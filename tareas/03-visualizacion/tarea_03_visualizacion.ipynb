# %% [markdown]
# # Tarea 04 — Visualización de Datos con Matplotlib
#
# **Instrucciones:** Completa cada celda de código con tu respuesta.
# Usarás la interfaz orientada a objetos de Matplotlib (`fig, ax = plt.subplots()`).

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dataset de trabajo
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
# Out:
# c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ---
# ## Parte 1 — Figura y ejes

# %% [markdown]
# **P1.** Crea una figura con `plt.subplots()` de tamaño 8×5.
# Haz un gráfico de línea con los primeros 20 valores de `sepal_length`.
# Agrega título `"Longitud del sépalo"` y etiquetas en ambos ejes.

# %%
# Tu respuesta aquí


plt.figure(figsize=(8, 5))
plt.plot(df["sepal_length"].head(20))
plt.title("Longitud del sépalo")
plt.xlabel("Índice")
plt.ylabel("Longitud (cm)")
plt.show()

# %% [markdown]
# ---
# ## Parte 2 — Gráfico de barras

# %% [markdown]
# **P2.** Calcula el promedio de `petal_length` por especie (`species`) y guárdalo en una variable.
# Luego crea un **gráfico de barras vertical** con esos promedios.
# Agrega título y etiquetas en ambos ejes.

# %%
# Tu respuesta aquí

df_petal_length_by_species = df.groupby("species")["petal_length"].mean()
plt.figure(figsize=(8, 5))
df_petal_length_by_species.plot(kind="bar")
plt.title("Promedio de longitud del pétalo por especie")
plt.xlabel("Especie")
plt.ylabel("Promedio de longitud del pétalo (cm)")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ---
# ## Parte 3 — Dispersión (scatter plot)

# %% [markdown]
# **P3.** Crea un **gráfico de dispersión** (scatter) con `sepal_length` en el eje X y `sepal_width` en el eje Y.
# Usa un color diferente para cada especie (puedes filtrar el DataFrame tres veces o usar un bucle).
# Agrega leyenda, título y etiquetas.

# %%
especies = df["species"].unique()
colores = ["blue", "orange", "green"]

fig, ax = plt.subplots(figsize=(8, 5))


# Tu respuesta aquí: itera sobre especies y colores para graficar cada grupo

for i, (especie, color) in enumerate(zip(especies, colores)):
    df_especie = df[df["species"] == especie]
    ax.scatter(df_especie["sepal_length"], df_especie["sepal_width"], color=color, label=especie)
ax.set_title("Gráfico de dispersión: Sepal Length vs Sepal Width")
ax.set_xlabel("Sepal Length (cm)")
ax.set_ylabel("Sepal Width (cm)")
ax.legend()
plt.show()

# %% [markdown]
# ---
# ## Parte 4 — Histograma

# %% [markdown]
# **P4.** Crea un **histograma** de la columna `petal_width` con 15 bins.
# Agrega una línea vertical punteada en el valor de la media con `ax.axvline()`.
# Agrega título y etiquetas.

# %%
# Tu respuesta aquí

plt.hist(df["petal_width"], bins=15, alpha=0.7)
plt.axvline(df["petal_width"].mean(), color="red", linestyle="dashed", linewidth=2, label="Media")
plt.title("Histograma de Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frecuencia")
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Parte 5 — Guardar figura

# %% [markdown]
# **P5.** Recrea el gráfico de barras de P2 y guárdalo como imagen PNG en `output/promedios_iris.png`.
# Usa `dpi=100` y `bbox_inches="tight"`.

# %%
import os
os.makedirs("output", exist_ok=True)

# Tu respuesta aquí

plt.figure(figsize=(8, 5))
df_petal_length_by_species.plot(kind="bar")
plt.title("Promedio de longitud del pétalo por especie")
plt.xlabel("Especie")
plt.ylabel("Promedio de longitud del pétalo (cm)")
plt.xticks(rotation=0)
plt.savefig("output/promedios_iris.png", dpi=100, bbox_inches="tight")
plt.show()
